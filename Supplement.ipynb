# %%
import numpy as np
import pandas as pd
import datetime as dt
import matplotlib.pyplot as plt 
import os
# %matplotlib widget
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_18232\3569049687.py:2: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Lenovo\\Snow_Fox_Analysis'

# %%
swe=pd.read_csv("C:/Users/Lenovo/Desktop/TC_brief/Hourly_File_SWE.csv")

# %%
SWE_data=swe[["Date","SWE"]]

# %%
SWE_data
# Out:
#                   Date          SWE
# 0      11/13/2019 2:00  2.443269584
# 1      11/13/2019 3:00  2.448126304
# 2      11/13/2019 4:00  2.448126304
# 3      11/13/2019 5:00  2.443269584
# 4      11/13/2019 6:00  2.426298087
# ...                ...          ...
# 16155   9/16/2021 5:00  127.2972751
# 16156   9/16/2021 6:00  126.4212706
# 16157   9/16/2021 7:00  127.2972751
# 16158   9/16/2021 8:00  128.1770697
# 16159   9/16/2021 9:00  128.7393132
#
# [16160 rows x 2 columns]

# %%
SWE_data["Date"]=pd.to_datetime(SWE_data["Date"])
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_10220\3158349918.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   SWE_data["Date"]=pd.to_datetime(SWE_data["Date"])

# %%
SWE_data['SWE'] = pd.to_numeric(SWE_data['SWE'], errors='coerce')
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_10220\2423094480.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   SWE_data['SWE'] = pd.to_numeric(SWE_data['SWE'], errors='coerce')

# %%
SWE_data.loc[8550]
# Out:
# Date    2020-11-03 08:00:00
# SWE                     NaN
# Name: 8550, dtype: object

# %%
SWE_data["SWE_hourly"]=SWE_data["SWE"].diff()
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_10220\427252711.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   SWE_data["SWE_hourly"]=SWE_data["SWE"].diff()

# %%
SWE_data["SWE_hourly"]=SWE_data["SWE_hourly"]*10
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_10220\1636937182.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   SWE_data["SWE_hourly"]=SWE_data["SWE_hourly"]*10

# %%
SWE_data.head()
# Out:
#                  Date       SWE  SWE_hourly
# 0 2019-11-13 02:00:00  2.443270         NaN
# 1 2019-11-13 03:00:00  2.448126    0.048567
# 2 2019-11-13 04:00:00  2.448126    0.000000
# 3 2019-11-13 05:00:00  2.443270   -0.048567
# 4 2019-11-13 06:00:00  2.426298   -0.169715

# %%
plt.figure(figsize=(10,8))
plt.plot(SWE_data["Date"].values, SWE_data["SWE_hourly"].values)
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
SWE_data.set_index(SWE_data["Date"],inplace=True, drop=True)

# %%
SWE_data.head()
# Out:
#                                    Date       SWE  SWE_hourly
# Date
# 2019-11-13 02:00:00 2019-11-13 02:00:00  2.443270         NaN
# 2019-11-13 03:00:00 2019-11-13 03:00:00  2.448126    0.004857
# 2019-11-13 04:00:00 2019-11-13 04:00:00  2.448126    0.000000
# 2019-11-13 05:00:00 2019-11-13 05:00:00  2.443270   -0.004857
# 2019-11-13 06:00:00 2019-11-13 06:00:00  2.426298   -0.016971

# %%
fig,ax=plt.subplots(nrows=2,ncols=1,sharex=True,figsize=(10,8))

# %%
ax[0].plot(SWE_data["SWE_cum_observation"], linewidth=1,linestyle="-",color="blue",label="AWS-H$_{SnowFox}$")
